# %%
from pandas import read_csv
from pandas import set_option

from numpy import set_printoptions

from matplotlib import pyplot

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from scipy.stats import ks_2samp
from scipy import stats

import woe as w

import pandas as pd

import numpy as np

#from woe import compute_ks
#from woe import eval_data_summary

# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np
from sklearn import tree
from sklearn.model_selection import GridSearchCV

# Figures inline and set visualization style
# %matplotlib inline
sns.set()

# %%
train_data.info()
train_data.Name.tail()
# Extract Title from Name, store in column and plot barplot
train_data['Title'] = train_data.Name.apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))
fig, ax = plt.subplots(figsize=(15,7))
sns.countplot(x='Title', data=train_data,ax=ax);
plt.xticks(rotation=45);
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Cabin_Str1     204 non-null object
# Title          891 non-null object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 97.5+ KB

# %%
import sys
sys.version
# scikit-learn
import woe.eval as ev
import woe.feature_process as fp
import woe.GridSearch as gs

dir(woe)
help(woe.__package__)
#feature_process()
#plot_ks()
# Out:
# Help on package woe:
#
# NAME
#     woe
#
# PACKAGE CONTENTS
#     GridSearch
#     config
#     eval
#     feature_process
#     ftrl
#
# FILE
#     c:\programdata\anaconda3\lib\site-packages\woe\__init__.py

# %%
# ?woe

compute_ks(train_data['Survived'],train_data)
# WOE package calculations
eval_feature_summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a4f9e3f80902> in <module>()
#       1 get_ipython().run_line_magic('pinfo', 'woe')
#       2
# ----> 3 compute_ks(train_data['Survived'],train_data)
#       4 # WOE package calculations
#
# NameError: name 'compute_ks' is not defined

# %%
x,y = (5,2)
print(x,y)
# Out:
# 5 2

# %% [markdown]
# ## Titanic Dataset
#
# We have 3 datasets:
#
# -**train.csv**
# -**test.csv**
# -**gender_submission.csv**

# %%
print('Single Quotes')
print("double quotes")
five = 'hello'
print(value1, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
# Out:
# Single Quotes
# double quotes

# %%
print('can do this:'+five)
x = "He said, \"Hello there!\" "
print(x)
a = 3.564
print("a = ", a)
print("a = \n", a)
# Out:
# can do this:hello
# He said, "Hello there!"
# a =  3.564
# a =
#  3.564

# %%
pwd()
# Out:
# 'C:\\Users\\matthias_mathaes\\Documents\\Python_Scripts\\machine_learning_project'

# %%
##### load dataset

train = 'Data/train.csv'
test = 'Data/test.csv' #note: this not my testing, but is Kaggle submission
train_data = read_csv(train)
test_data = read_csv(test)

# %%
##### test and look at 
# train_data.shape
# toPredict_data.shape

train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6baff7ffc835> in <module>()
#       1 # WOE package calculations
# ----> 2 compute_ks(train_data)
#
# NameError: name 'compute_ks' is not defined

# %% [markdown]
# ## Descriptive Statistics
# Summarize the distribution of instances across classes in your dataset.
# Summarize your data using descriptive statistics.
# Understand the relationships in your data using correlations.

# %%
df =train_data.dtypes == 'object'

#df == 'object'
#df1 = df.drop(df == 'object',axis = 1)
#  df1 = df[['a','d']]

# %%
train_data.dtypes
#print(train_data.dtypes)

#counts of response variable
train_data['Survived'].value_counts()/len(train_data['Survived'])


#get frequencies
#train_data['Survived'].unique()


train_data['Cabin'].value_counts()
# Out:
# C23 C25 C27        4
# B96 B98            4
# G6                 4
# D                  3
# F2                 3
# F33                3
# E101               3
# C22 C26            3
# B57 B59 B63 B66    2
# B77                2
# E8                 2
# D35                2
# F G73              2
# C93                2
# C92                2
# B28                2
# E121               2
# C78                2
# B5                 2
# C125               2
# D17                2
# B22                2
# C65                2
# C123               2
# C68                2
# E67                2
# B58 B60            2
# F4                 2
# D33                2
# E33                2
#                   ..
# D48                1
# C47                1
# D6                 1
# D7                 1
# C106               1
# D45                1
# C82                1
# E40                1
# C128               1
# C46                1
# C49                1
# D46                1
# ...

# %%
#cabin_c1
# Replace variable with manipulated variable
train_data['Cabin_Str1'] = train_data['Cabin'].str.slice(0,1).values
train_data.head(7)
#cabin_c1=train_data['Cabin'].str.slice(0,1).values
train_data.groupby(['Survived','Sex','Pclass'])['Cabin_Str1'].value_counts()
# Out:
# Survived  Sex     Pclass  Cabin_Str1
# 0         female  1       C              3
#                   2       E              1
#                   3       G              2
#           male    1       C             21
#                           B             12
#                           A              8
#                           D              7
#                           E              7
#                           T              1
#                   2       D              1
#                           F              1
#                   3       F              4
# 1         female  1       B             27
#                           C             24
#                           D             16
#                           E             10
#                           A              1
#                   2       F              4
#                           E              3
#                           D              2
#                   3       G              2
# ...

# %%
# Replace variable with manipulated variable
train_data['Cabin'] = train_data['Cabin'].str.slice(0,1).values
#cabin_c1=train_data['Cabin'].str.slice(0,1).values


train_data.describe(include=['object'])

# get counts of new variabl
train_data.Cabin.value_counts()


# fillna function

#.value_counts()

#.groupby('Cabin')
#train_data['Cabin'].str.slice(0,1))

#value_counts()
# Out:
#   File "<ipython-input-113-8ca2867eb97b>", line 12
#     --
#       ^
# SyntaxError: invalid syntax

# %%
train_data.groupby('Cabin').size()
np.unique.train_data('Cabin')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-dbe84711681b> in <module>()
#       1 train_data.groupby('Cabin').size()
# ----> 2 unique.train_data('Cabin')
#
# NameError: name 'unique' is not defined

# %%
#train_data.groupby('Survived').size()
#train_data.groupby(['Survived','Pclass','Sex'])['Age'].mean().unstack()

train_data.groupby('Cabin').size()
freqs = (train_data['Cabin'].value_counts()/len(train_data['Cabin']))
set_printoptions(precision=4)
freqs

# fillna function
#pd.fillna

ff = train_data['Age'].fillna(-1)
ff

#Selects just the categorical data
#my_series.select_dtypes(include=['O']) 


#train_data.groupby(['Cabin'])['Survived'].mean()
#train_data.groupby(['Cabin'])['Survived'].count()
#.count()
#train_data.groupby(['Survived']).count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-f1441a1d249b> in <module>()
#      16 #my_series.select_dtypes(include=['O'])
#      17
# ---> 18 train_data['Cabin'].infer_freq()
#      19
#      20 #train_data.groupby(['Cabin'])['Survived'].mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'infer_freq'

# %%
cab = train_data['Cabin'].head(10)
cab['Cabin_Orig'] =train_data['Cabin']

cab.head(10)

#cab1 = train_data['Cabin']

#c = np.concatenate((cab,cab1),axis = 1)

#cab = np.hstack(train_data['Cabin'])
#cab

#cab_new = cab.str.slice(0,4,2)
#cab_new.head(10)
#cab.value_counts()
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
Survived_counts = train_data.groupby('Survived').size()
print(Survived_counts[1])
train_data.shape[0]
train_data.drop
# Out:
# 342
# <bound method NDFrame.drop of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# ...

# %%
# dimension of data
nrows= train_data.shape[0]
ncols= train_data.shape[1]
maxrows = len(train_data)
#Survived_counts = train_data.groupby('Survived').size()
#Survived_counts


train_data['Survived'].value_counts()


# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html
#data.shape
#class_counts
#data.ftypes
#data.T # transposes data set
#data.size
#data.loc

# data methods
#data.groupby('preg', axis=0).mean() # returns mean of
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
train_data.ftypes
# Out:
# PassengerId      int64:dense
# Survived         int64:dense
# Pclass           int64:dense
# Name            object:dense
# Sex             object:dense
# Age            float64:dense
# SibSp            int64:dense
# Parch            int64:dense
# Ticket          object:dense
# Fare           float64:dense
# Cabin           object:dense
# Embarked        object:dense
# dtype: object

# %%
freqs = (train_data['Survived'].value_counts()/len(train_data['Survived']))
set_printoptions(precision=4)
freqs
# Out:
# 0    0.62
# 1    0.38
# Name: Survived, dtype: float64

# %%
freq_sur=pd.Series(freqs.values)
freq_sur
# Out:
# 0    0.616162
# 1    0.383838
# dtype: float64

# %%
train_data.loc[:,train_data.dtypes = object] 
#list(train_data.columns.values(dtype == 'object'))
#names = train_data.name(include=['object'])
# Out:
#   File "<ipython-input-198-9d6501ecb1ef>", line 1
#     train_data.loc[:,train_data.dtypes = object]
#                                        ^
# SyntaxError: invalid syntax

# %%
col_names = train_data.select_dtypes(include = "object").columns.values
col_names

for names in col_names:
    print(names)
# Out:
# Name
# Sex
# Ticket
# Cabin
# Embarked

# %%
train_data.head(5)
train_data.dtypes("object")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-235-ddd44fdf8ff5> in <module>()
#       1 train_data.head(5)
# ----> 2 train_data.dtypes("object")
#       3
#
# TypeError: 'Series' object is not callable

# %%
list(train_data.columns.values)
table_list = list(train_data.columns.values)

list(train_data.columns.values)

dtype
     #(dtype == 'object'))
#(include=['object'])
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
# write loop that takes all type = object variables and computes frequencies
#train_data.describe(include=['object'])

col_names = train_data.select_dtypes(include = "object").columns.values
col_names

for names in col_names:
    print(names)    
    # Counts
    cnt = pd.Series(train_data['names'].value_counts(),name = 'Counts')
    # Freqs
    frq = pd.Series((train_data['names'].value_counts()/len(train_data['names'])),name ='Freq')
    a2 =pd.concat([sur_counts,freqs],axis=0)
    #a1 = pd.concat([sur_counts,freqs],axis=1)
    print('\n\n',names) 

#for x in range(0, 3):
#    print "We're on time %d" % (x)
# Out:
# Name
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'names'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-280-73b8ff4a8847> in <module>()
#       8     print(names)
# ...

# %%
#Create new age variable
#age = 38
#train_data['Age']
if (train_data['Age'] >= 0 ):
  print ("Baby or Toddler.")
else:
    print ("You're not eligible to buy a ticket.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-287-2a7f3b44c6b7> in <module>()
#       2 #age = 38
#       3 #train_data['Age']
# ----> 4 if (train_data['Age'] >= 0 ):
#       5   print ("Baby or Toddler.")
#       6 else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Extract Title from Name, store in column and plot barplot
data['Title'] = data.Name.apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))
sns.countplot(x='Title', data=data);
plt.xticks(rotation=45);

# %%
train_data['Age'].head
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
a2 =pd.concat([sur_counts,freqs],axis=0)

a1 = pd.concat([sur_counts,freqs],axis=1)

#print(a2 + "\n \n" + a1)
print(a2,"\n\n\n",a1)

#print("\n \n")
#print(a1)
# how to make output more copy ready?
# Out:
# 0    549.000000
# 1    342.000000
# 0      0.616162
# 1      0.383838
# dtype: float64
#
#
#     Counts      Freq
# 0     549  0.616162
# 1     342  0.383838

# %%
len(train_data)
# Freqs
freqs = pd.Series((train_data['Survived'].value_counts()/len(train_data['Survived'])),name ='Freq')


# Counts
sur_counts = pd.Series(train_data['Survived'].value_counts(),name = 'Counts')
sur_counts_new = sur_counts.assign(freq_sur=Series(freqs.values))

# initialize new dataframe
#cf_sur = []
# Series(np.random.randn(sLength), index=df1.index)
#freqs

# stack counts and freqs
#cf_sur = []
#cf_sur
#cf_sur = cf_sur.append(sur_counts)
#print(cf_sur)
#cf_sur = cf_sur.extend(freqs)
#cf_sur
#(value for name,value in locals().items, if name.startswith)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-181-49bb28e68bec> in <module>()
#       6 # Counts
#       7 sur_counts = pd.Series(train_data['Survived'].value_counts(),name = 'Counts')
# ----> 8 sur_counts_new = sur_counts.assign(freq_sur=Series(freqs.values))
#       9
#      10 # initialize new dataframe
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'assign'

# %%
set_option('display.width', 100)
set_option('precision', 2)
set_option('display.height',100)
set_option('display.max_columns',10)
train_data.describe()
# Summary Statistics of Numeric Variables
stats_num = train_data.describe(include=["int64","float64"])

# Summary Statistics of Character Variables (objects)
#train_data.describe(include=['0'])
stats_char = train_data.describe(include=["object"])

print(stats_num,"\n\n\n ",stats_char) 
stats_num
stats_char

# Can also do this combined
train_data.describe(percentiles = [.01,.05,.10,.25,.5,.75,.90,.95,.99],include="all")
#train_data.describe(percentiles = [.01,.05,.10,.25,.5,.75,.90,.95,.99],include=['number'])
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count       891.00    891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00      0.38    2.31   29.70    0.52    0.38   32.20
# std         257.35      0.49    0.84   14.53    1.10    0.81   49.69
# min           1.00      0.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50      0.00    2.00   20.12    0.00    0.00    7.91
# 50%         446.00      0.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50      1.00    3.00   38.00    1.00    0.00   31.00
# max         891.00      1.00    3.00   80.00    8.00    6.00  512.33
#
#
#                                         Name   Sex Ticket Cabin Embarked
# count                                  891   891    891   204      889
# unique                                 891     2    681     8        3
# top     Frolicher, Miss. Hedwig Margaritha  male   1601     C        S
# ...

# %%
train_data.describe(include="all")
# Out:
#         PassengerId  Survived  Pclass                                Name   Sex    ...      Parch  \
# count        891.00    891.00  891.00                                 891   891    ...     891.00
# unique          NaN       NaN     NaN                                 891     2    ...        NaN
# top             NaN       NaN     NaN  Frolicher, Miss. Hedwig Margaritha  male    ...        NaN
# freq            NaN       NaN     NaN                                   1   577    ...        NaN
# mean         446.00      0.38    2.31                                 NaN   NaN    ...       0.38
# std          257.35      0.49    0.84                                 NaN   NaN    ...       0.81
# min            1.00      0.00    1.00                                 NaN   NaN    ...       0.00
# 25%          223.50      0.00    2.00                                 NaN   NaN    ...       0.00
# ...

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html
# data set is 768 rows × 9 columns
train_data.shape
#class_counts
train_data.ftypes
train_data.T # transposes data set
train_data.size
#train_data.loc

# data methods
#data.groupby('preg', axis=0).mean() # returns mean of
# Out:
# 10692

# %%
#### feature extraction - create new variables
train_data['Age2'] 
if train_data['Age']
# Out:
# (891, 12)

# %%
##### need to know if NAs and stuff
## For Numeric variables
train_data.describe()
train_data.size
## get frequncies of factor levels
train_data.isnull().sum()

####### results
# age has some missing according to count
# survived is binay
# PassengerId is not predictive
# some Fare shows 0; they got on free? or this wrong?
# Pclass looks ordinal, others continuous
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
num_miss = train_data.isnull().sum()/891
num_miss
train_data.groupby(['Survived'])['Age'].count()
train_data.groupby(['Survived','Pclass','Sex'])['Age'].count().unstack()
# Out:
# Sex              female  male
# Survived Pclass
# 0        1            3    61
#          2            6    84
#          3           55   215
# 1        1           82    40
#          2           68    15
#          3           47    38

# %%
## missing values

num_miss = train_data.isnull().sum()/891
#count(train_data)
num_miss


#df.isnull().sum(axis=0)

## counts missing rows
#df.isnull().sum(axis=1)
#train_data.apply(lambda x: x.count(), axis=1)
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
## looking at means by certain groupings
train_data.groupby(['Pclass'])['Fare'].mean()
train_data.groupby(['Pclass'])['Fare'].mean()

train_data.groupby(['Survived','Pclass'])['Fare'].mean().unstack()

train_data.groupby(['Survived','Pclass'])['Age'].mean().unstack()

train_data.groupby(['Survived','Pclass','Sex'])['Age'].mean().unstack()

train_data.groupby(['Survived','Pclass','Sex'])['Age'].count().unstack()

#train_data.groupby(['Survived','Pclass'])['Fare'].count().unstack()



#grouped_data = train_data.groupby(['Survived', 'Pclass'])
#grouped_data = train_data.groupby(['Survived', 'Sex'])
#grouped_data = train_data.groupby(['Survived', 'Age'])

#grouped_data = train_data.groupby(['Survived', 'Cabin'])

#grouped_data_1 = train_data.query("Fare > 100").groupby(['Survived', 'Sex'])
#grouped_data_1.describe()

#train_data.groupby(['Survived', 'Cabin'])
    
#grouped_data['Parch'].describe()

#df = train_data.groupby(['Survived','Pclass'])['Fare'].mean().unstack().reset_index()
#print (df)
# Out:
# Sex              female  male
# Survived Pclass
# 0        1            3    61
#          2            6    84
#          3           55   215
# 1        1           82    40
#          2           68    15
#          3           47    38

# %%
train_data.hist()
pyplot.show()

# %%
set_option('display.width', 100)
set_option('precision', 3)
correlations = train_data.corr(method='pearson')
print(correlations)
# Out:
#              PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# PassengerId        1.000    -0.005  -0.035  0.037 -0.058 -0.002  0.013
# Survived          -0.005     1.000  -0.338 -0.077 -0.035  0.082  0.257
# Pclass            -0.035    -0.338   1.000 -0.369  0.083  0.018 -0.549
# Age                0.037    -0.077  -0.369  1.000 -0.308 -0.189  0.096
# SibSp             -0.058    -0.035   0.083 -0.308  1.000  0.415  0.160
# Parch             -0.002     0.082   0.018 -0.189  0.415  1.000  0.216
# Fare               0.013     0.257  -0.549  0.096  0.160  0.216  1.000

# %%
##### curious how many Fare are zero, may need to impute
class_counts = train_data.groupby('Fare').size()
print(class_counts) # 15 out of 891, not bad
# Out:
# Fare
# 0.0000      15
# 4.0125       1
# 5.0000       1
# 6.2375       1
# 6.4375       1
# 6.4500       1
# 6.4958       2
# 6.7500       2
# 6.8583       1
# 6.9500       1
# 6.9750       2
# 7.0458       1
# 7.0500       7
# 7.0542       2
# 7.1250       4
# 7.1417       1
# 7.2250      12
# 7.2292      15
# 7.2500      13
# 7.3125       1
# 7.4958       3
# 7.5208       1
# 7.5500       4
# 7.6292       1
# 7.6500       4
# 7.7250       1
# 7.7292       1
# 7.7333       4
# 7.7375       2
# 7.7417       1
#             ..
# 80.0000      2
# 81.8583      1
# 82.1708      2
# 83.1583      3
# 83.4750      2
# 86.5000      3
# 89.1042      2
# 90.0000      4
# 91.0792      2
# 93.5000      2
# 106.4250     2
# 108.9000     2
# 110.8833     4
# 113.2750     3
# 120.0000     4
# 133.6500     2
# 134.5000     2
# 135.6333     3
# 146.5208     2
# 151.5500     4
# 153.4625     3
# 164.8667     2
# 211.3375     3
# 211.5000     1
# 221.7792     1
# 227.5250     4
# 247.5208     2
# ...

# %%
#clean up-drop columns categorical, convert gender to numerical
train_data = train_data.drop(columns=['PassengerId','Name','Ticket','Cabin','Embarked'], axis=1)

#just realized,need to do all this to testing data also...

# %%
train_data.head(4)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch    Fare
# 0         0       3    male  22.0      1      0   7.250
# 1         1       1  female  38.0      1      0  71.283
# 2         1       3  female  26.0      0      0   7.925
# 3         1       1  female  35.0      1      0  53.100

# %%
# repeat for test data to submit to competition
# note we havn't made our normal train test split yet 
toPredict_data = toPredict_data.drop(columns=['PassengerId','Name','Ticket','Cabin','Embarked'], axis=1)
# Whoops... need to keep the PassengerId... i think...? or can i add it back in later... <shug>

# %%
mapping = {'male': 0, 'female': 1}
train_data = train_data.replace({'Sex': mapping})

# this was a bit painful and lots of Googling, not sure if need to cast to boolean, maybe

# %%
mapping = {'male': 0, 'female': 1}
toPredict_data = toPredict_data.replace({'Sex': mapping})

# %%
toPredict_data.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch    Fare
# 0       3    0  34.5      0      0   7.829
# 1       3    1  47.0      1      0   7.000
# 2       2    0  62.0      0      0   9.688
# 3       3    0  27.0      0      0   8.662
# 4       3    1  22.0      1      1  12.287

# %%
train_data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch    Fare
# 0         0       3    0  22.0      1      0   7.250
# 1         1       1    1  38.0      1      0  71.283
# 2         1       3    1  26.0      0      0   7.925
# 3         1       1    1  35.0      1      0  53.100
# 4         0       3    0  35.0      0      0   8.050

# %%
##### i'll need to impute to toPredict_data also because
##### I noticed missing values in Age i forgot about when trying to array it 
##### fixing it here

train_data["Age"].fillna(train_data["Age"].mean(), inplace=True)
# inplace=True means that the changes are saved to the df right away

# %%
##### need to remember to prep the submitting test data as we go
toPredict_data["Age"].fillna(toPredict_data["Age"].mean(), inplace=True)

# %%
array = train_data.values # not the labels 
X = array[:,1:8]
Y = array[:,0]

# %%
# prepare models
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = KFold(n_splits=10, random_state=7)
	cv_results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# boxplot algorithm comparison
fig = pyplot.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()
# Out:
# LR: 0.794632 (0.031257)
# LDA: 0.795743 (0.041936)
# KNN: 0.712747 (0.043048)
# CART: 0.790112 (0.036996)
# NB: 0.785655 (0.020737)
# SVM: 0.693683 (0.051387)

# %%
# create pipeline
estimators = []

estimators.append(('standardize', StandardScaler()))
estimators.append(('LR', LogisticRegression()))

model = Pipeline(estimators)

# evaluate pipeline
kfold = KFold(n_splits=10, random_state=7)

results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.7867665418227217

# %%
## fix the one missing Fare value
toPredict_data["Fare"].fillna(toPredict_data["Fare"].mean(), inplace=True)

# %%
## might as well replace the zero fare values with mean also while i'm at it
Fare_mean = toPredict_data["Fare"].mean(skipna=True)
toPredict_data["Fare"]=toPredict_data.Fare.mask(toPredict_data.Fare == 0,Fare_mean)

# %%
# Rescale toPredictData - be  better to build the rescaled data on combined set (I think)
arrayT = toPredict_data.values #not the labels ?
YT = arrayT[:,0:6]

# %%
# 1. Rescale the test data
# 2. Fit the model from original X and Y built
# 3. Apply this model, predicting on the YT (the 'test.csv' file already prepped)
StandardScaler(YT)
model.fit(X, Y)
predicted = model.predict(YT).astype(int)

# %%
# re-get the test file for the passengerIds (a bit hackish), add predictions column to it using Pandas
filenameTest = 'test.csv'
toPredict_data2 = read_csv(filenameTest)
toPredict_data2['Survived'] = pd.Series(data=predicted)

# %%
# pulling only 2 columns to conform to submission standard to upload, 
submission = pd.DataFrame({'PassengerId': toPredict_data2.loc[:, 'PassengerId'],
                           'Survived': toPredict_data2.loc[:, 'Survived']})

# %%
# dump prdictions to file - but NOT with the row index - using PassengerID as index
submission.to_csv("submission.csv", index = False)
